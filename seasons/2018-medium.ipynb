# %%
# imports
from ff_espn_api import League
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# 2018 league
league_id = 140547
year = 2018
swid = '{2CF7EB07-52CE-4A77-B5CF-93261DF48AB1}'
espn_s2 = 'AEBnBUS4C%2FEQt6V8HTh9HgHbGP3KC4rc4rdspzt3JA8wO5r9i7p8%2BYbqnTyEgLEFT6Qrd9DXKfxjOkhXPC6DeMKKxW%2BO16DgudBu3cMe6avfjogteybWbtRk7aTe%2FIHbftKlsNZ2XTBkVFdCuXriaZjpTBeLFxdXLhfkmYreo6EhtAKzSn0qWfEZhsmdcF4wGOqeLxYXXJSLCQIVJcffhaSie6lhv2NVK1KbCDvkW1Q468GTXHkmED4hsneBBoI0o5s%3D'

# %%
# instatiate league object
league = League(league_id, year, espn_s2, swid)

# %%
# list of attributes
league.__dir__()
# Out:
# ['league_id',
#  'year',
#  'ENDPOINT',
#  'teams',
#  'draft',
#  'player_map',
#  'espn_s2',
#  'swid',
#  'cookies',
#  'current_week',
#  'nfl_week',
#  'status',
#  'settings',
#  '__module__',
#  '__doc__',
#  '__init__',
#  '__repr__',
#  '_fetch_league',
#  '_fetch_teams',
#  '_fetch_settings',
#  '_fetch_players',
#  '_fetch_draft',
#  'load_roster_week',
#  'standings',
#  'top_scorer',
#  'least_scorer',
#  'most_points_against',
#  'top_scored_week',
#  'least_scored_week',
#  'get_team_data',
#  'league_trades',
#  'scoreboard',
#  'box_scores',
#  'power_rankings',
#  'free_agents',
#  '__dict__',
#  '__weakref__',
#  '__hash__',
#  '__str__',
#  '__getattribute__',
#  '__setattr__',
#  '__delattr__',
#  '__lt__',
#  '__le__',
#  '__eq__',
#  '__ne__',
#  '__gt__',
#  '__ge__',
#  '__new__',
#  '__reduce_ex__',
#  '__reduce__',
#  '__subclasshook__',
#  '__init_subclass__',
#  '__format__',
#  '__sizeof__',
#  '__dir__',
#  '__class__']

# %%
league.teams
# Out:
# [Team(BLACK MCCAFFREY YA OOOUUUUUUU),
#  Team(chi na),
#  Team(The Story of OJ),
#  Team(WHITE GURLEY YA OOOUUUUUUU),
#  Team(Hit the  SaQuon),
#  Team(Eric is adopted),
#  Team(My Ball  Zach Ertz),
#  Team(JJ Glory Hole: Flaccid Revenge),
#  Team(luck my balls),
#  Team(Kirks  2nd Cousin),
#  Team(SuperBowl 52 Eagles Won),
#  Team(Team Picart)]

# %%
league.standings()
# Out:
# [Team(BLACK MCCAFFREY YA OOOUUUUUUU),
#  Team(WHITE GURLEY YA OOOUUUUUUU),
#  Team(JJ Glory Hole: Flaccid Revenge),
#  Team(chi na),
#  Team(luck my balls),
#  Team(Hit the  SaQuon),
#  Team(Kirks  2nd Cousin),
#  Team(My Ball  Zach Ertz),
#  Team(The Story of OJ),
#  Team(Team Picart),
#  Team(Eric is adopted),
#  Team(SuperBowl 52 Eagles Won)]

# %%
league.draft[0].playerName
# Out:
# 'Todd Gurley II'

# %%
league.draft[0].__dict__
# Out:
# {'team': Team(Kirks  2nd Cousin),
#  'playerId': 2977644,
#  'playerName': 'Todd Gurley II',
#  'round_num': 1,
#  'round_pick': 1,
#  'bid_amount': 0,
#  'keeper_status': False}

# %%
league.draft
# Out:
# [Pick(Todd Gurley II, Team(Kirks  2nd Cousin)),
#  Pick(David Johnson, Team(JJ Glory Hole: Flaccid Revenge)),
#  Pick(Le'Veon Bell, Team(The Story of OJ)),
#  Pick(Antonio Brown, Team(SuperBowl 52 Eagles Won)),
#  Pick(Ezekiel Elliott, Team(chi na)),
#  Pick(Saquon Barkley, Team(Hit the  SaQuon)),
#  Pick(Alvin Kamara, Team(BLACK MCCAFFREY YA OOOUUUUUUU)),
#  Pick(DeAndre Hopkins, Team(luck my balls)),
#  Pick(Julio Jones, Team(Eric is adopted)),
#  Pick(Leonard Fournette, Team(My Ball  Zach Ertz)),
#  Pick(Melvin Gordon, Team(Team Picart)),
#  Pick(Davante Adams, Team(WHITE GURLEY YA OOOUUUUUUU)),
#  Pick(Christian McCaffrey, Team(WHITE GURLEY YA OOOUUUUUUU)),
#  Pick(Kareem Hunt, Team(Team Picart)),
#  Pick(Devonta Freeman, Team(My Ball  Zach Ertz)),
#  Pick(Odell Beckham Jr., Team(Eric is adopted)),
#  Pick(Dalvin Cook, Team(luck my balls)),
#  Pick(Michael Thomas, Team(BLACK MCCAFFREY YA OOOUUUUUUU)),
#  Pick(LeSean McCoy, Team(Hit the  SaQuon)),
# ...

# %%
league.teams[-1].__dict__
# Out:
# {'team_id': 12,
#  'team_abbrev': 'PICA',
#  'team_name': 'Team Picart',
#  'division_id': 1,
#  'wins': 6,
#  'losses': 7,
#  'points_for': 1330.9,
#  'points_against': 1409.68,
#  'owner': 'dj Picart',
#  'streak_length': 1,
#  'streak_type': 'WIN',
#  'standing': 0,
#  'final_standing': 10,
#  'logo_url': '',
#  'roster': [Player(Melvin Gordon),
#   Player(Doug Baldwin),
#   Player(Aaron Rodgers),
#   Player(Sammy Watkins),
#   Player(Kenyan Drake),
#   Player(Kenny Stills),
#   Player(C.J. Uzomah),
#   Player(Mitchell Trubisky),
#   Player(Robbie Gould),
#   Player(Steelers D/ST),
#   Player(Redskins D/ST),
#   Player(Ryan Succop),
#   Player(Josh Adams),
#   Player(Giovani Bernard),
#   Player(Chris Conley),
#   Player(Kelvin Benjamin)],
#  'schedule': [Team(BLACK MCCAFFREY YA OOOUUUUUUU),
#   Team(Kirks  2nd Cousin),
#   Team(chi na),
#   Team(Hit the  SaQuon),
#   Team(My Ball  Zach Ertz),
#   Team(JJ Glory Hole: Flaccid Revenge),
#   Team(Eric is adopted),
# ...

# %% [markdown]
# It just so happens that there are 16 weeks in fantasy football and 16 slots. For some dumb reason, people don't have a full roster. So in order to convert to a df, the columns must have the same number of values. So for every person without a full roster, I impute a value of 'a', then drop the column completely after converting to a df.

# %%
# get roster
league.teams[0].roster
# Out:
# [Player(Alvin Kamara),
#  Player(JuJu Smith-Schuster),
#  Player(Deshaun Watson),
#  Player(Sony Michel),
#  Player(Kenny Golladay),
#  Player(Brandin Cooks),
#  Player(Todd Gurley II),
#  Player(Greg Zuerlein),
#  Player(Vikings D/ST),
#  Player(Josh Reynolds),
#  Player(Elijah McGuire),
#  Player(Trey Burton),
#  Player(C.J. Anderson),
#  Player(Kareem Hunt)]

# %%
league.teams[0].roster.append('a')

# %%
league.teams[0].roster.append('a')

# %%
league.teams[0].roster
# Out:
# [Player(Alvin Kamara),
#  Player(JuJu Smith-Schuster),
#  Player(Deshaun Watson),
#  Player(Sony Michel),
#  Player(Kenny Golladay),
#  Player(Brandin Cooks),
#  Player(Todd Gurley II),
#  Player(Greg Zuerlein),
#  Player(Vikings D/ST),
#  Player(Josh Reynolds),
#  Player(Elijah McGuire),
#  Player(Trey Burton),
#  Player(C.J. Anderson),
#  Player(Kareem Hunt),
#  'a',
#  'a']

# %%
league.teams[-2].__dict__
# Out:
# {'team_id': 11,
#  'team_abbrev': 'AGU',
#  'team_name': 'SuperBowl 52 Eagles Won',
#  'division_id': 3,
#  'wins': 3,
#  'losses': 10,
#  'points_for': 1175.18,
#  'points_against': 1385.73,
#  'owner': 'Devan Peppers',
#  'streak_length': 4,
#  'streak_type': 'LOSS',
#  'standing': 0,
#  'final_standing': 12,
#  'logo_url': 'http://g.espncdn.com/lm-static/logo-packs/ffl/GridironWarriors-MartinLaksman/warriors-10.svg',
#  'roster': [Player(Antonio Brown),
#   Player(Rob Gronkowski),
#   Player(Corey Clement),
#   Player(Danny Amendola),
#   Player(Derek Carr),
#   Player(Donte Moncrief),
#   Player(Duke Johnson Jr.),
#   Player(Cody Parkey),
#   Player(Bengals D/ST),
#   Player(Nelson Agholor),
#   Player(Larry Fitzgerald),
#   Player(Stefon Diggs),
#   Player(Carlos Hyde),
#   Player(Tevin Coleman),
#   Player(Drew Brees)],
#  'schedule': [Team(The Story of OJ),
#   Team(luck my balls),
#   Team(WHITE GURLEY YA OOOUUUUUUU),
#   Team(JJ Glory Hole: Flaccid Revenge),
# ...

# %%
league.teams[-2].roster.append('a')

# %%
for i in range(len(league.teams)):
    print(len(league.teams[i].roster))
# Out:
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16

# %% [markdown]
# ### Create league dataframe

# %%
columns = list(league.teams[0].__dict__.keys())
columns.remove('roster')
columns
# Out:
# ['team_id',
#  'team_abbrev',
#  'team_name',
#  'division_id',
#  'wins',
#  'losses',
#  'points_for',
#  'points_against',
#  'owner',
#  'streak_length',
#  'streak_type',
#  'standing',
#  'final_standing',
#  'logo_url',
#  'schedule',
#  'scores',
#  'outcomes',
#  'mov']

# %%
# create df for league
league_2018 = pd.DataFrame()
for d in range(len(league.teams)):
    temp_df = pd.DataFrame.from_dict(pd.DataFrame(league.teams[d].__dict__, columns=columns))
    league_2018 = league_2018.append(temp_df)

# %%
league_2018
# Out:
#     team_id team_abbrev                      team_name  division_id  wins  \
# 0         1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1    12
# 1         1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1    12
# 2         1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1    12
# 3         1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1    12
# 4         1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1    12
# 5         1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1    12
# 6         1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1    12
# 7         1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1    12
# 8         1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1    12
# 9         1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1    12
# 10        1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1    12
# 11        1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1    12
# ...

# %%
# check my team
league_2018[league_2018['owner'] == 'dj Picart']
# Out:
#     team_id team_abbrev    team_name  division_id  wins  losses  points_for  \
# 0        12        PICA  Team Picart            1     6       7      1330.9
# 1        12        PICA  Team Picart            1     6       7      1330.9
# 2        12        PICA  Team Picart            1     6       7      1330.9
# 3        12        PICA  Team Picart            1     6       7      1330.9
# 4        12        PICA  Team Picart            1     6       7      1330.9
# 5        12        PICA  Team Picart            1     6       7      1330.9
# 6        12        PICA  Team Picart            1     6       7      1330.9
# 7        12        PICA  Team Picart            1     6       7      1330.9
# 8        12        PICA  Team Picart            1     6       7      1330.9
# 9        12        PICA  Team Picart            1     6       7      1330.9
# 10       12        PICA  Team Picart            1     6       7      1330.9
# ...

# %%
# change the index to 'week'
league_2018.index.names = ['week']

# %%
# add 'week' column
league_2018.reset_index(level='week', inplace=True)

# %%
# add +1 to every week
league_2018['week'] = league_2018['week'].apply(lambda x: x + 1)

# %%
league_2018
# Out:
#      week  team_id team_abbrev                      team_name  division_id  \
# 0       1        1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1
# 1       2        1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1
# 2       3        1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1
# 3       4        1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1
# 4       5        1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1
# 5       6        1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1
# 6       7        1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1
# 7       8        1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1
# 8       9        1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1
# 9      10        1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1
# 10     11        1        PICA  BLACK MCCAFFREY YA OOOUUUUUUU            1
# ...

# %%
league_2018.columns
# Out:
# Index(['week', 'team_id', 'team_abbrev', 'team_name', 'division_id', 'wins',
#        'losses', 'points_for', 'points_against', 'owner', 'streak_length',
#        'streak_type', 'standing', 'final_standing', 'logo_url', 'schedule',
#        'scores', 'outcomes', 'mov'],
#       dtype='object')

# %% [markdown]
# ### Draft Order
#
# Need to do this step manually for every year.

# %%
# get draft order
for i in range(len(league.teams)):
    print(league.teams[i].team_id, league.teams[i].team_name, league.teams[i].owner)
# Out:
# 1 BLACK MCCAFFREY YA OOOUUUUUUU Jon Picart
# 2 chi na Patrick Davis
# 3 The Story of OJ Tevin Cropper
# 4 WHITE GURLEY YA OOOUUUUUUU Kevin Paragna
# 5 Hit the  SaQuon Kuljeet Sidhu
# 6 Eric is adopted Marc Cudiamat
# 7 My Ball  Zach Ertz Michael Verhulst
# 8 JJ Glory Hole: Flaccid Revenge Cody Leonard
# 9 luck my balls Eric Cudiamat
# 10 Kirks  2nd Cousin Gary Watson
# 11 SuperBowl 52 Eagles Won Devan Peppers
# 12 Team Picart dj Picart

# %%
# map according to draft order
# no easy way to do this but manually
league_2018['draft_order'] = league_2018['team_id'].map({1:7, 2:5, 3:3, 4:12, 5:6, 6:9, 7:10, 8:2, 9:8, 10:1, 11:4, 12:11})

# %%
league_2018.T
# Out:
#                                                               0    \
# week                                                            1
# team_id                                                         1
# team_abbrev                                                  PICA
# team_name                           BLACK MCCAFFREY YA OOOUUUUUUU
# division_id                                                     1
# wins                                                           12
# losses                                                          1
# points_for                                                1517.56
# points_against                                            1309.71
# owner                                                  Jon Picart
# streak_length                                                   2
# streak_type                                                   WIN
# standing                                                        0
# ...

# %%
# drop unecessary columns
league_2018 = league_2018.drop(['division_id', 'team_id', 'team_abbrev', 'team_name', 'streak_length', 'streak_type', 'logo_url', 'standing', 'outcomes', 'schedule'], axis=1)

# %%
# check my team
league_2018[league_2018['owner'] == 'dj Picart']
# Out:
#      week  wins  losses  points_for  points_against      owner  \
# 176     1     6       7      1330.9         1409.68  dj Picart
# 177     2     6       7      1330.9         1409.68  dj Picart
# 178     3     6       7      1330.9         1409.68  dj Picart
# 179     4     6       7      1330.9         1409.68  dj Picart
# 180     5     6       7      1330.9         1409.68  dj Picart
# 181     6     6       7      1330.9         1409.68  dj Picart
# 182     7     6       7      1330.9         1409.68  dj Picart
# 183     8     6       7      1330.9         1409.68  dj Picart
# 184     9     6       7      1330.9         1409.68  dj Picart
# 185    10     6       7      1330.9         1409.68  dj Picart
# 186    11     6       7      1330.9         1409.68  dj Picart
# 187    12     6       7      1330.9         1409.68  dj Picart
# 188    13     6       7      1330.9         1409.68  dj Picart
# 189    14     6       7      1330.9         1409.68  dj Picart
# ...

# %%
# wildcard winner in playoffs
# must do manually if the 6th place is not automatically the wild card winner
# league_2018['playoffs'] = np.where(league_2018['final_standing'] == 7, 1, league_2018['final_standing'])

# %%
# playoffs category for all other teams
# <= 5 for wild card not in top 6
league_2018['playoffs'] = np.where(league_2018['final_standing'] <= 6, 1, 0)

# %%
league_2018[league_2018.index == 0].sort_values('final_standing')
# Out:
#    week  wins  losses  points_for  points_against       owner  final_standing  \
# 0     1    12       1     1517.56         1309.71  Jon Picart               1
#
#    scores   mov  draft_order  playoffs
# 0   126.5  15.6            7         1

# %% [markdown]
# ## Data Analysis

# %%
# playoffs
league_2018[league_2018['playoffs'] == 1].corr()['final_standing'][:].sort_values()
# Out:
# points_for       -0.911205
# wins             -0.855219
# scores           -0.246922
# draft_order      -0.224950
# mov              -0.216309
# week              0.000000
# points_against    0.148401
# losses            0.855219
# final_standing    1.000000
# playoffs               NaN
# Name: final_standing, dtype: float64

# %%
# overall final standings
league_2018.corr()['final_standing'][:].sort_values()
# Out:
# points_for       -0.903740
# playoffs         -0.869048
# wins             -0.803024
# scores           -0.340812
# mov              -0.267556
# draft_order      -0.020979
# week              0.000000
# points_against    0.056576
# losses            0.803024
# final_standing    1.000000
# Name: final_standing, dtype: float64

# %%
corr = league_2018.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
corr = league_2018.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-07b5457b55f9> in <module>
# ----> 1 corr = league_2018['final_standing'].corr()
#       2 # Generate a mask for the upper triangle
#       3 mask = np.zeros_like(corr, dtype=np.bool)
#       4 mask[np.triu_indices_from(mask)] = True
#       5
#
# TypeError: corr() missing 1 required positional argument: 'other'

# %%
sns.pairplot(league_2018[['final_standing', 'points_for', 'points_against', 'wins', 'mov']]);

# %%
from sklearn import linear_model

# %%
X = league_2018.drop(['final_standing', 'owner'], axis=1)
y = league_2018['final_standing']

# %%
lr = linear_model.LinearRegression()

# %%
lr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lr.coef_
# Out:
# array([ 8.07209986e-04, -1.62647507e-01,  1.62647507e-01, -1.66133131e-02,
#         9.39805677e-03,  9.09842695e-04, -2.13623429e-03,  1.46057748e-01,
#        -2.39246969e+00])
